# %% [markdown]
# <a href="https://colab.research.google.com/github/finterstellar/lecture/blob/master/23%EC%8B%A0%EC%9E%85%EA%B5%90%EC%9C%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install finterstellar

# %%
import finterstellar as fs

# %%
df1 = fs.get_price('AAPL', start_date='2000-01-01')

# %%
df2 = fs.get_price('MSFT', start_date='2000-01-01')

# %%
df3 = fs.get_price_kr('005930', start_date='2000-01-01')

# %%
pd.concat([df1, df2, df3])
