# %% [markdown]
# [코딩을 시작하기 전에](https://youtu.be/aAQ0QeXuAm0)

# %% [markdown]
# # 파이썬 기본 문법

# %% [markdown]
# ## 결괏값 출력
# ```
# print(출력내용)
# ```

# %%
print(1)

# %%
print('A')

# %% [markdown]
# ### 이어쓰기, 붙여쓰기
# 여러 값을 한꺼번에 찍고 싶으면 괄호 안에 `,` 나 `+` 를 이용해서 여러개를 붙여주면 되는데,
# * `,`를 이용하면 둘 사이에 스페이스가 들어가면서 합쳐지고
# * `+`를 이용하면 스페이스 없이 합쳐짐

# %%
print('A', 'B', 'C')
print('A' + 'B' + 'C')
print('Number:', 1)

# %% [markdown]
# # = vs. ==
# ##= : 할당
# a = 1
# ##== : 같다
# a == 1

# %% [markdown]
# ### 대소문자 구분

# %%
A = '변수1'
a = '변수2'
print('A:', A)
print('a:', a)

# %% [markdown]
# ### 들여쓰기에 민감❗

# %%
print(1)
print(2)

# %%
print(1)
    print(2)

# %% [markdown]
# ### 여러 줄 쓰기

# %%
B = '문장을 만들어 볼까요'
b = '긴 문장을' + \
    '한 줄로 만들어 볼까요?'
print(B)
print(b)

# %% [markdown]
# ### 한 줄로 꼭 쓰고싶다면?
# ```
# print(출력내용, end='')
# ```

# %%
print('A')
print('B')

# %%
print('A', end='')
print('B')

# %% [markdown]
# ### 사용자에게 입력받기
# ```
# input()
# ```

# %%
input()

# %%
a = input('숫자를 입력하세요')
print(a)

# %% [markdown]
# ## 주석
# ```
# # 한 줄 주석
# '''
#     여러 줄 주석
# '''
# ```

# %%
# 이것은 한 줄 주석입니다.
p = 1    # 이 줄어서는 여기서 부터가 주석입니다.
'''
삼중 따옴표 사이에 들어와도 다 주석입니다.
여러 주 ㄹ주석을 입력할 때 사용합니다.
'''
"""
p = 100
주석은 파이썬에 입력되지 않기 때문에 출력되지 않습니다.
"""
print(p)

# %% [markdown]
# ---
# # 변수의 형식 (자료형)

# %%
i = 1   # 정수형 변수
type(i)

# %%
f = 1.0    # 소수형 변수
type(f)

# %%
print(i)

# %%
i = float(i)    # 정수형을 소수형으로 변환
print(i)

# %%
i2 = 1.2345
i2

# %%
i2 = int(i2)    # 소수형을 정수형으로 변환
i2

# %%
s = '문자'    # '' 또는 "" 로 씌워주면 문자형 변수
type(s)

# %%
# 문자형 변수는 여러 줄로 입력 가능
s2 = '''나도
문자
'''
print(s2)

# %% [markdown]
# ### (홀)따옴표 안에 들어간 숫자는 문자로 인식❗

# %%
a = '1'
type(a)

# %% [markdown]
# 형변환을 통해 숫자로 인식하도록 만들 수 있음

# %%
b = int(a)    # 문자를 숫자로 변환
type(b)

# %% [markdown]
# 하지만, 숫자 말고 다른게 섞여있으면 안됨

# %%
int('숫자1')

# %% [markdown]
# 천단위 콤마(,)도 컴퓨터에게는 문자일 뿐

# %%
int('123,456')

# %%
int('123456')

# %% [markdown]
# ---
# # 사칙연산

# %%
x = 3
print(x)

# %%
print(x * 2)

# %%
print(x ** 2)

# %%
print(x ** 3)

# %% [markdown]
# 문자로 사칙연산을 하려 한다면?

# %%
y = '1'
print(y)

# %%
print(y + y)

# %% [markdown]
# 숫자로 변환하면 비로소 제대로 연산

# %%
print(int(y) + int(y))

# %% [markdown]
# ---
# # 문자열 합치기, 자르기

# %%
w1 = 'Py'
w2 = 'thon'
word = w1 + w2
word

# %% [markdown]
# ```
#  +---+---+---+---+---+---+
#  | P | y | t | h | o | n |
#  +---+---+---+---+---+---+
#  0   1   2   3   4   5   6
# -6  -5  -4  -3  -2  -1
# ```

# %%
word[0:2]    # 카운트는 0부터 시작, 마지막은 불포함

# %%
word[1:4]    # 1부터 4 전까지

# %%
word[:4]    # 처음부터 4 전까지

# %%
word[4:]    # 4부터 마지막까지

# %% [markdown]
# ---
# # 고급 자료형

# %% [markdown]
# 다음 주가데이터를 변수에 저장하시오

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 리스트

# %%
prices = [100, 200, 300, 400, 500]
prices

# %%
prices[2]

# %%
prices[:2]

# %%
prices[3]

# %%
prices.append(600)
prices

# %%
len(prices)

# %%
prices.remove(400)
prices

# %%
len(prices)

# %%
prices.extend([700,200])
prices

# %%
len(prices)

# %% [markdown]
# ### 집합

# %%
A = {1, 2, 3, 4, 5}
B = {4, 5, 6, 7, 8}
type(A)

# %%
A | B    # 합집합. A.union(B) 도 가능

# %%
A & B    # 교집합. A.intersection(B) 도 가능

# %%
A - B    # 차집합

# %% [markdown]
# ### 딕셔너리

# %%
d = {'Kim':123, 'Lee':456}
type(d)

# %%
d['Choi'] = 789
d

# %%
d['Kim']

# %%
del d['Lee']
d

# %%
d['Park'] = 134
len(d)

# %%
d.items()

# %%
d.keys()

# %%
d.values()

# %% [markdown]
# ---
# # 반복문
# 코딩의 이유

# %% [markdown]
# for
#
# ```
# for 변수 in 범위:
#     실행할 내용
# ```

# %%
prices

# %%
for p in prices:
    print('가격은', p, '입니다.')

# %% [markdown]
# while
#
# ```
# while 범위:
#     실행할 내용
# ```

# %%
i = 0
while i < 10:
    print(i)
    i = i + 1

# %% [markdown]
# ## 리스트 다루기

# %%
prices = [100, 200, 300, 400, 500]

# %%
for p in prices:     # prices 에 담긴 내용을 변수 p에 할당해서 루프를 돌림
    print('가격은 ', p, ' 입니다.')

# %% [markdown]
# ### 딕셔너리 다루기

# %%
d = {'Kim':123, 'Lee':456, 'Park':789}

# %% [markdown]
# 딕셔너리 내의 아이템들을 키:밸류 쌍으로 가져올 때는
# ```
# dict.items()
# ```
# 키만 가져올 때는
# ```
# dict.keys()
# ```
# 밸류만 가져올 때는
# ```
# dict.values()
# ```

# %%
for k, v in d.items():
    print(k, v)

# %%
for k in d.keys():
    print(k)

# %%
for v in d.values():
    print(v)

# %% [markdown]
# ---
# # 제어문
# 로직의 탄생

# %% [markdown]
# 컴퓨터에게 생각하도록 하려면 `if` 를 이용
#
# if문의 구조
#
# ```
# if 조건 1:
#     조건 1이 참일 때 실행할 내용
# elif 조건 2:
#     조건 2가 참일 때 실행할 내용
# else:
#     모두 거짓일 때 실행할 내용
# ```

# %%
p = int(input())

if p < 10000:
    print('매수')
elif p > 10000:
    print('매도')
else:
    print('중립')

# %% [markdown]
# ---
# # 함수
# 귀차니즘 극복을 위한 궁극의 도구

# %% [markdown]
# 함수 만들기
# ```
# def 함수명(받아올 값):
#     실행할 내용
# ```
# 함수의 실행
# ```
# 함수명(넣어줄 값)
# ```

# %%
def f(n):
    for i in range(n):
        print('#', end='')

# %%
f(10)

# %%
f(20)

# %%
f(1)

# %% [markdown]
# # 외부 라이브러리 사용

# %% [markdown]
# import 라이브러리명
#
#
# ```
# import pandas
# import pandas as pd
# ```

# %% [markdown]
# 라이브러리 설치
#
#
# ```
# pip install 라이브러리명
# ```

# %% [markdown]
# # 알고리즘이 중요!?
# 퍼포먼스를 좌우하는 것은 코딩 경력이 아니라 알고리즘

# %%
# %%time
sum = 0
for i in range(1,1000001):
    sum += i
print(sum)

# %%
# %%time
sum = 0
sum = (1 + 1000000) * 500000
print(sum)

# %% [markdown]
# ## 단어 맞히기 게임

# %%
#@title Before we enter...
import random

word_set = ['word', 'card', 'msci', 'into', 'look', 'room', 'noon', 'take',
            'book', 'more', 'sure', 'nerd', 'cold', 'cool', 'bold', 'load',
            'mood', 'lane', 'line', 'core', 'wood', 'zoom', 'lazy', 'busy']
answer = random.choice(word_set)

hit = 0
trial = 1
guess = input('Input any character : ')
while hit < len(answer):
    hit_this = 0
    if trial > 1:
        guess_plus = input('Input another character : ')
        guess += guess_plus
    print('({})'.format(trial), end=' ')
    for i in range(len(answer)):
        if answer[i] in guess:
            print(answer[i], end=' ')
            hit_this += 1
        else:
            print('_', end=' ')
    print()
    hit = hit_this
    trial += 1

# %%
import random

# %%
word_set = ['word', 'card', 'msci', 'into', 'look', 'room', 'noon', 'take',
            'book', 'more', 'sure', 'nerd', 'cold', 'cool', 'bold', 'load',
            'mood', 'lane', 'line', 'core', 'wood', 'zoom', 'lazy', 'busy']

# %%
answer = random.choice(word_set)

# %% [markdown]
# 사용자에게 글자를 받아오는 방법은? 구글링!

# %%
guess = input('Input any character :')

# %% [markdown]
# 문자열 내에서 특정 문자의 위치 찾는 방법?

# %% [markdown]
# 문자열.find() 를 써도 되지만, 답을 표시하기 편하게 노가다로 해보자.

# %%
for i in range(len(answer)):    # 답의 길이 만큼 반복
    if answer[i] == guess:    # 받아온 글자가 해당 글자와 같다면
        print(answer[i], end=' ')    # 해당 위치에 글자 표시
    else:
        print('_', end=' ')    # 오답이면 밑줄만 표시

# %% [markdown]
# 두번째 시도 부터는?

# %%
guess_plus = input('Input another character :')
guess += guess_plus    # 받아온 단어 누적
print(guess)

# %%
for i in range(len(answer)):
    if answer[i] in guess:    # 받아온 글자가 답에 포함되어 있다면
        print(answer[i], end=' ')
    else:
        print('_', end=' ')

# %% [markdown]
# 다 맞힐 때 까지 반복

# %%
hit = 0
trial = 1
guess = input('Input any character : ')    # 최초 글자 받아오기
while hit < len(answer):    # hit 수가 글자 수 보다 작을때만 실행
    hit_this = 0    # 정답 수 초기화
    if trial > 1:    # 두 번째 시기부터 실행
        guess_plus = input('Input another character : ')
        guess += guess_plus    # 받아온 단어 누적
    print('({})'.format(trial), end=' ')    # 몇 번째 시도인지 표시
    for i in range(len(answer)):    # 답의 길이 만큼 반복
        if answer[i] in guess:    # 받아온 글자가 답에 포함되어 있다면
            print(answer[i], end=' ')    # 해당 위치에 글자 표시
            hit_this += 1    # 정답 수 증가
        else:
            print('_', end=' ')    # 오답이면 밑줄만 표시
    print()    # 줄바꿈을 위해 공백 표시
    hit = hit_this    # hit 수 갱신
    trial += 1    # 시도 수 증가
