# %% [markdown]
# <a href="https://colab.research.google.com/github/finterstellar/lecture/blob/master/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EA%B8%B0%EC%B4%88_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install finterstellar
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import finterstellar as fs

# %%
df = fs.get_price('AAPL')
df
# Out:
#              AAPL
# 2022-01-05 174.92
# 2022-01-06 172.00
# 2022-01-07 172.17
# 2022-01-10 172.19
# 2022-01-11 175.08
# ...           ...
# 2022-12-28 126.04
# 2022-12-29 129.61
# 2022-12-30 129.93
# 2023-01-03 125.07
# 2023-01-04 126.36
#
# [251 rows x 1 columns]

# %%
fs.rsi(df)
# Out:
#              AAPL   rsi
# 2022-01-05 174.92   NaN
# 2022-01-06 172.00   NaN
# 2022-01-07 172.17   NaN
# 2022-01-10 172.19   NaN
# 2022-01-11 175.08   NaN
# ...           ...   ...
# 2022-12-28 126.04 29.71
# 2022-12-29 129.61 36.85
# 2022-12-30 129.93 37.46
# 2023-01-03 125.07 32.33
# 2023-01-04 126.36 34.88
#
# [251 rows x 2 columns]

# %%
fs.draw_chart(df, left='rsi', right='AAPL')

# %%
fs.indicator_to_signal(df, factor='rsi', buy=40, sell=60)
# Out:
# 2022-01-05    zero
# 2022-01-06    zero
# 2022-01-07    zero
# 2022-01-10    zero
# 2022-01-11    zero
#               ...
# 2022-12-28     buy
# 2022-12-29     buy
# 2022-12-30     buy
# 2023-01-03     buy
# 2023-01-04     buy
# Name: trade, Length: 251, dtype: object

# %%
fs.position(df)
# Out:
# 2022-01-05
# 2022-01-06    zz
# 2022-01-07    zz
# 2022-01-10    zz
# 2022-01-11    zz
#               ..
# 2022-12-28    ll
# 2022-12-29    ll
# 2022-12-30    ll
# 2023-01-03    ll
# 2023-01-04    ll
# Name: position, Length: 251, dtype: object

# %%
fs.evaluate(df)
# Out:
#              AAPL  diff   au   ad   rsi trade position  position_chart  rtn  \
# 2022-01-05 174.92   NaN  NaN  NaN   NaN  zero                        0 1.00
# 2022-01-06 172.00 -2.92  NaN  NaN   NaN  zero       zz               0 1.00
# 2022-01-07 172.17  0.17  NaN  NaN   NaN  zero       zz               0 1.00
# 2022-01-10 172.19  0.02  NaN  NaN   NaN  zero       zz               0 1.00
# 2022-01-11 175.08  2.89  NaN  NaN   NaN  zero       zz               0 1.00
# ...           ...   ...  ...  ...   ...   ...      ...             ...  ...
# 2022-12-28 126.04 -3.99 0.72 1.71 29.71   buy       ll               1 1.00
# 2022-12-29 129.61  3.57 0.93 1.59 36.85   buy       ll               1 1.00
# 2022-12-30 129.93  0.32 0.88 1.47 37.46   buy       ll               1 1.00
# 2023-01-03 125.07 -4.86 0.82 1.72 32.33   buy       ll               1 1.00
# 2023-01-04 126.36  1.29 0.85 1.59 34.88   buy       ll               1 1.00
#
#             daily_rtn  acc_rtn  acc_rtn_dp  mdd  bm_mdd
# ...

# %%
df.tail(10)
# Out:
#              AAPL  diff   au   ad   rsi trade position  position_chart  rtn  \
# 2022-12-20 132.30 -0.07 0.80 1.59 33.63   buy       ll               1 1.00
# 2022-12-21 135.45  3.15 0.97 1.47 39.73   buy       ll               1 1.00
# 2022-12-22 132.23 -3.22 0.90 1.60 36.08   buy       ll               1 1.00
# 2022-12-23 131.86 -0.37 0.84 1.51 35.68   buy       ll               1 1.00
# 2022-12-27 130.03 -1.83 0.78 1.53 33.66   buy       ll               1 1.00
# 2022-12-28 126.04 -3.99 0.72 1.71 29.71   buy       ll               1 1.00
# 2022-12-29 129.61  3.57 0.93 1.59 36.85   buy       ll               1 1.00
# 2022-12-30 129.93  0.32 0.88 1.47 37.46   buy       ll               1 1.00
# 2023-01-03 125.07 -4.86 0.82 1.72 32.33   buy       ll               1 1.00
# 2023-01-04 126.36  1.29 0.85 1.59 34.88   buy       ll               1 1.00
#
#             daily_rtn  acc_rtn  acc_rtn_dp  mdd  bm_mdd
# 2022-12-20       1.00     0.85      -15.08 0.76    0.74
# ...

# %%
fs.performance(df, rf_rate=.04)
# Out:
# CAGR: -20.04%
# Accumulated return: -18.89%
# Average return: 0.78%
# Benchmark return : -20.92%
# Number of trades: 3
# Number of win: 1
# Hit ratio: 33.33%
# Investment period: 0.9yrs
# Sharpe ratio: -0.59
# MDD: -28.12%
# Benchmark MDD: -30.11%

# %%
fs.draw_trade_results(df)

# %%
df = fs.get_price('BTI', start_date='2020-01-01')
df
# Out:
#              BTI
# 2020-01-02 42.87
# 2020-01-03 43.66
# 2020-01-06 44.08
# 2020-01-07 44.73
# 2020-01-08 45.41
# ...          ...
# 2022-12-28 40.16
# 2022-12-29 39.98
# 2022-12-30 39.98
# 2023-01-03 40.44
# 2023-01-04 40.41
#
# [758 rows x 1 columns]

# %%
fs.envelope(df, w=20, spread=0.1)
# Out:
#              BTI  center    ub    lb
# 2020-01-02 42.87     NaN   NaN   NaN
# 2020-01-03 43.66     NaN   NaN   NaN
# 2020-01-06 44.08     NaN   NaN   NaN
# 2020-01-07 44.73     NaN   NaN   NaN
# 2020-01-08 45.41     NaN   NaN   NaN
# ...          ...     ...   ...   ...
# 2022-12-28 40.16   41.17 45.29 37.06
# 2022-12-29 39.98   41.11 45.22 37.00
# 2022-12-30 39.98   41.01 45.11 36.91
# 2023-01-03 40.44   40.92 45.01 36.83
# 2023-01-04 40.41   40.82 44.90 36.74
#
# [758 rows x 4 columns]

# %%
fs.draw_band_chart(df)

# %%
fs.band_to_signal(df, buy='D', sell='B')
fs.position(df)
fs.evaluate(df)
fs.performance(df, rf_rate=.4)
# Out:
# CAGR: 0.30%
# Accumulated return: 0.88%
# Average return: 0.66%
# Benchmark return : -8.26%
# Number of trades: 2
# Number of win: 1
# Hit ratio: 50.00%
# Investment period: 2.9yrs
# Sharpe ratio: -2.43
# MDD: -25.82%
# Benchmark MDD: -38.66%

# %%
fs.band_to_signal(df, buy='A', sell='B')
fs.position(df)
fs.evaluate(df)
fs.performance(df, rf_rate=.4)
# Out:
# CAGR: -0.55%
# Accumulated return: -1.59%
# Average return: -0.52%
# Benchmark return : -8.26%
# Number of trades: 3
# Number of win: 2
# Hit ratio: 66.67%
# Investment period: 2.9yrs
# Sharpe ratio: -13.78
# MDD: -3.24%
# Benchmark MDD: -38.66%

# %%
fs.draw_trade_results(df)

# %%
# Out:
# CAGR: 0.30%
# Accumulated return: 0.88%
# Average return: 0.66%
# Benchmark return : -8.26%
# Number of trades: 2
# Number of win: 1
# Hit ratio: 50.00%
# Investment period: 2.9yrs
# Sharpe ratio: -2.43
# MDD: -25.82%
# Benchmark MDD: -39.23%

# %%
fs.draw_trade_results(df)

# %%
df = fs.get_price('GOOGL', start_date='2020-01-01')

# %%
fs.bollinger(df, w=20, k=2)
# Out:
#             GOOGL  center     ub    lb
# 2020-01-02  68.43     NaN    NaN   NaN
# 2020-01-03  68.08     NaN    NaN   NaN
# 2020-01-06  69.89     NaN    NaN   NaN
# 2020-01-07  69.76     NaN    NaN   NaN
# 2020-01-08  70.25     NaN    NaN   NaN
# ...           ...     ...    ...   ...
# 2022-12-28  86.02   93.15 102.75 83.54
# 2022-12-29  88.45   92.52 101.59 83.45
# 2022-12-30  88.23   91.88 100.21 83.55
# 2023-01-03  89.12   91.32  98.68 83.95
# 2023-01-04  88.08   90.75  97.15 84.34
#
# [758 rows x 4 columns]

# %%
fs.band_to_signal(df, buy='A', sell='C')
# Out:
# 2020-01-02    zero
# 2020-01-03    zero
# 2020-01-06    zero
# 2020-01-07    zero
# 2020-01-08    zero
#               ...
# 2022-12-28    zero
# 2022-12-29    zero
# 2022-12-30    zero
# 2023-01-03    zero
# 2023-01-04    zero
# Name: trade, Length: 758, dtype: object

# %%
fs.position(df)
fs.evaluate(df)
fs.performance(df, rf_rate=.04)
# Out:
# CAGR: -1.64%
# Accumulated return: -4.74%
# Average return: -0.14%
# Benchmark return : 21.14%
# Number of trades: 15
# Number of win: 7
# Hit ratio: 46.67%
# Investment period: 2.9yrs
# Sharpe ratio: -0.28
# MDD: -22.27%
# Benchmark MDD: -44.32%

# %%
fs.draw_band_chart(df)

# %%
fs.draw_trade_results(df)
